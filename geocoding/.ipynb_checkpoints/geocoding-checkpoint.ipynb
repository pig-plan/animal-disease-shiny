# %% [markdown]
# GOOGLE MAPS GEOCODE API KEY : AIzaSyDvwglFuj1Ha8Fu09jYoPnKO_442oXcgKA

# %%
#-*- coding: utf-8 -*-

# %%
import pandas as pd
import geocoder
from geopy.geocoders import GoogleV3

# %%
geolocator = GoogleV3(api_key = "AIzaSyDvwglFuj1Ha8Fu09jYoPnKO_442oXcgKA")

# %%
df = pd.read_csv('../refined.csv')

# %%
df
# Out:
#       LKNTS_NM DGNSS_ENGN_NM  OCCRRNC_LVSTCKCNT LVSTCKSPC_NM  OCCRRNC_DE  \
# 0      돼지오제스키병       경기 남부지소                  1           돼지  2003-05-30
# 1          결핵병    강원 가축위생시험소                 26         소-젖소  2003-05-30
# 2         뉴캣슬병    전남 축산기술연구소              32200         닭-육계  2003-03-24
# 3        가금티프스       충남 공주지소               6500         닭-육계  2003-03-18
# 4        가금티프스    경기도축산위생연구소               1200         닭-육계  2003-04-10
# 5          결핵병       경기 동부지소                  1         소-육우  2003-04-15
# 6          결핵병    강원 가축위생시험소                  1         소-젖소  2003-05-30
# 7      돼지오제스키병       경기 남부지소                  1           돼지  2003-05-30
# 8        가금티프스    경기도축산위생연구소                 30        닭-산란계  2003-05-23
# 9        가금티프스       충남 공주지소               4500         닭-육계  2003-05-14
# 10         결핵병    강원 가축위생시험소                  1         소-젖소  2003-05-30
# 11     돼지오제스키병       경기 남부지소                  2           돼지  2003-05-30
# ...

# %%
df['FARM_LOCPLC'][1:10]
# Out:
# 1        강원도 철원군 김화읍 청양리
# 2       전라남도 나주시 봉황면 덕림리
# 3       충청남도 공주시 정안면 상룡리
# 4        경기도 화성시 장안면 어은리
# 5        경기도 여주시 대신면 가산리
# 6        강원도 철원군 갈말읍 지경리
# 7    경기도 용인시 처인구 포곡읍 유운리
# 8        경기도 화성시 양감면 용소리
# 9       충청남도 공주시 의당면 수촌리
# Name: FARM_LOCPLC, dtype: object

# %%
df['location'] = geolocator.geocode( df.loc[1:3,]['FARM_LOCPLC'] )

# %%
df
# Out:
#       LKNTS_NM DGNSS_ENGN_NM  OCCRRNC_LVSTCKCNT LVSTCKSPC_NM  OCCRRNC_DE  \
# 0      돼지오제스키병       경기 남부지소                  1           돼지  2003-05-30
# 1          결핵병    강원 가축위생시험소                 26         소-젖소  2003-05-30
# 2         뉴캣슬병    전남 축산기술연구소              32200         닭-육계  2003-03-24
# 3        가금티프스       충남 공주지소               6500         닭-육계  2003-03-18
# 4        가금티프스    경기도축산위생연구소               1200         닭-육계  2003-04-10
# 5          결핵병       경기 동부지소                  1         소-육우  2003-04-15
# 6          결핵병    강원 가축위생시험소                  1         소-젖소  2003-05-30
# 7      돼지오제스키병       경기 남부지소                  1           돼지  2003-05-30
# 8        가금티프스    경기도축산위생연구소                 30        닭-산란계  2003-05-23
# 9        가금티프스       충남 공주지소               4500         닭-육계  2003-05-14
# 10         결핵병    강원 가축위생시험소                  1         소-젖소  2003-05-30
# 11     돼지오제스키병       경기 남부지소                  2           돼지  2003-05-30
# ...

# %%
geolocator.geocode( df.loc[1:3,]['FARM_LOCPLC'][2] ).latitude
# Out:
# 34.9208461

# %%
df.loc[1:3,]['FARM_LOCPLC'].apply(geolocator.geocode)
# Out:
# 1    (Cheongyang-ri, Gimhwa-eup, Cheorwon-gun, Gang...
# 2    (Deokrim-ri, Bonghwang-myeon, Naju-si, Jeollan...
# 3    (Sangryong-ri, Jeongan-myeon, Gongju-si, Chung...
# Name: FARM_LOCPLC, dtype: object

# %%
longitude = df['FARM_LOCPLC'].apply(lambda x: geolocator.geocode(x).longitude)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-8dfbaad6bdbb> in <module>()
# ----> 1 longitude = df['FARM_LOCPLC'].apply(lambda x: geolocator.geocode(x).longitude)
#
# /home/wooyol/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-57-8dfbaad6bdbb> in <lambda>(x)
# ----> 1 longitude = df['FARM_LOCPLC'].apply(lambda x: geolocator.geocode(x).longitude)
#
# ...

# %%
df['lng'] = longitude

# %%
df
# Out:
#       LKNTS_NM DGNSS_ENGN_NM  OCCRRNC_LVSTCKCNT LVSTCKSPC_NM  OCCRRNC_DE  \
# 0      돼지오제스키병       경기 남부지소                  1           돼지  2003-05-30
# 1          결핵병    강원 가축위생시험소                 26         소-젖소  2003-05-30
# 2         뉴캣슬병    전남 축산기술연구소              32200         닭-육계  2003-03-24
# 3        가금티프스       충남 공주지소               6500         닭-육계  2003-03-18
# 4        가금티프스    경기도축산위생연구소               1200         닭-육계  2003-04-10
# 5          결핵병       경기 동부지소                  1         소-육우  2003-04-15
# 6          결핵병    강원 가축위생시험소                  1         소-젖소  2003-05-30
# 7      돼지오제스키병       경기 남부지소                  1           돼지  2003-05-30
# 8        가금티프스    경기도축산위생연구소                 30        닭-산란계  2003-05-23
# 9        가금티프스       충남 공주지소               4500         닭-육계  2003-05-14
# 10         결핵병    강원 가축위생시험소                  1         소-젖소  2003-05-30
# 11     돼지오제스키병       경기 남부지소                  2           돼지  2003-05-30
# ...
